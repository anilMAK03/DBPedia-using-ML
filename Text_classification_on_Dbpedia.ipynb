# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
test_data = pd.read_csv('test.csv')
train_data = pd.read_csv('train.csv')
train_data
# Out:
#          1                                   E. D. Abbott Ltd  \
# 0        1                                     Schwan-Stabilo
# 1        1                                         Q-workshop
# 2        1                  Marvell Software Solutions Israel
# 3        1                        Bergan Mercy Medical Center
# 4        1                                 The Unsigned Guide
# 5        1                                  Rest of the world
# 6        1                                         Globoforce
# 7        1                                          Rompetrol
# 8        1                                    Wave Accounting
# 9        1                                 Angstrem (company)
# 10       1                                    I-innovate (UK)
# 11       1                                                JVC
# 12       1                                           Toei Bus
# 13       1                                  Tear Drop Records
# 14       1  Presses polytechniques et universitaires romandes
# 15       1                                           Websense
# 16       1                            Adventist Health System
# 17       1                                           CIB Bank
# 18       1                               Orfanato Music Group
# 19       1                                   SCAN Health Plan
# 20       1                                       Rudolf Kämpf
# 21       1                                   De Wendel family
# 22       1                         Mansfield Building Society
# 23       1                                     Witcomb Cycles
# 24       1                                Goldilocks Bakeshop
# 25       1                         Guardian Assurance Company
# 26       1                                             Shiply
# 27       1                    Orange Music Electronic Company
# 28       1                                  Rytec Corporation
# 29       1                              Cavity Search Records
# ...     ..                                                ...
# 559969  14                                                NME
# 559970  14                                       The Londoner
# 559971  14                        Formal Aspects of Computing
# 559972  14                                          Hayom Yom
# 559973  14                      Swords Against the Shadowland
# 559974  14            Aruvu Rezuru: Kikaijikake no Yōseitachi
# 559975  14                                  Tintin (magazine)
# 559976  14                     The Tenth Man (Chayefsky play)
# 559977  14                                  Dramatical Murder
# 559978  14               A Dictionary of Modern English Usage
# 559979  14                                            Assayad
# 559980  14                                   Loveless (manga)
# 559981  14                                The American Hebrew
# 559982  14                                Montanan (magazine)
# 559983  14                                  Black Out (novel)
# 559984  14                               Gold Digger (comics)
# 559985  14                             Dealer's Choice (play)
# 559986  14                                     Phuket Gazette
# 559987  14                          If I Forget Thee Oh Earth
# 559988  14                      The Lincoln Conspiracy (book)
# 559989  14                                 Endocrine Research
# 559990  14                           A Thousand Splendid Suns
# 559991  14                                     Western People
# 559992  14                            Mademoiselle (magazine)
# 559993  14                                Scoliosis (journal)
# 559994  14                                   Barking in Essex
# 559995  14                                   Science & Spirit
# 559996  14                             The Blithedale Romance
# 559997  14                                Razadarit Ayedawbon
# 559998  14                           The Vinyl Cafe Notebooks
#
#         Abbott of Farnham E D Abbott Limited was a British coachbuilding business based in Farnham Surrey trading under that name from 1929. A major part of their output was under sub-contract to motor vehicle manufacturers. Their business closed in 1972.
# 0        Schwan-STABILO is a German maker of pens for ...
# 1        Q-workshop is a Polish company located in Poz...
# 2        Marvell Software Solutions Israel known as RA...
# 3        Bergan Mercy Medical Center is a hospital loc...
# 4        The Unsigned Guide is an online contacts dire...
# 5        Within sports and games played at the interna...
# 6        Globoforce is a multinational company co-head...
# 7        The Rompetrol Group N.V. is a Romanian oil co...
# 8        Wave is the brand name for a suite of online ...
# 9        Angstrem Group (Russian: ОАО «Ангстрем» named...
# 10       I-innovate (UK) is a London-based independent...
# 11       Victor Company of Japan Ltd (日本ビクター株式会社 Nippo...
# 12       The Toei Bus (都営バス Toei Basu) is a bus servic...
# 13       Tear Drop Records was a record label founded ...
# 14       The Presses polytechniques et universitaires ...
# 15       Websense is a San Diego-based company special...
# 16       The Adventist Health System is a non-profit h...
# 17       CIB Bank is the second-biggest commercial ban...
# 18       Orfanato Music Group (OMG) is a Puerto Rican ...
# 19       SCAN Health Plan (SCAN) is a not-for-profit h...
# 20       Rudolf Kämpf is a porcelain manufacturer in t...
# 21       The de Wendel Family is an industrialist fami...
# 22       The Mansfield Building Society is a UK buildi...
# 23       Witcomb Cycles formerly known as Witcomb Ligh...
# 24       Goldilocks Bakeshop is a bakeshop chain based...
# 25       The Guardian Assurance Company was a very lar...
# 26       Shiply is a UK-based limited company providin...
# 27       Orange Music Electronic Company is a British ...
# 28       Rytec Corporation is an American manufacturer...
# 29       Cavity Search Records is a record label based...
# ...                                                   ...
# 559969   New Musical Express popularly known by the ac...
# 559970   The Londoner was a newsletter in the style of...
# 559971   Formal Aspects of Computing (FAC) is a peer-r...
# 559972   Hayom Yom (Hebrew: היום יום‎ Today is day ......
# 559973   Swords Against the Shadowland is a fantasy no...
# 559974   Aruvu Rezuru: Kikaijikake no Yōseitachi (アルヴ・...
# 559975   Tintin magazine (French: Le Journal de Tintin...
# 559976             The Tenth Man is a 1959 American play.
# 559977   Dramatical Murder (ドラマティカル マーダー Doramatikaru ...
# 559978   A Dictionary of Modern English Usage (1926) b...
# 559979   Assayad is a weekly Arabic news magazine publ...
# 559980   Loveless (ラブレス Raburesu) is an ongoing fantas...
# 559981   The American Hebrew was a weekly Jewish magaz...
# 559982   The Montanan is the University of Montana's a...
# 559983   Black Out is a psychological thriller by best...
# 559984   Gold Digger is a manga-style comic book serie...
# 559985   Dealer's Choice is a play by Patrick Marber f...
# 559986   The Phuket Gazette is a weekly English-langua...
# 559987   If I Forget Thee O Earth is a short story wri...
# 559988   The Lincoln Conspiracy is a book by David W. ...
# 559989   Endocrine Research is a peer-reviewed medical...
# 559990   A Thousand Splendid Suns is a 2007 novel by A...
# 559991   The Western People is a weekly local newspape...
# 559992   Mademoiselle was a women's magazine first pub...
# 559993   Scoliosis (ISSN 1748-7161) is an open-access ...
# 559994   Barking in Essex is a Black comedy play direc...
# 559995   Science & Spirit is a discontinued American b...
# 559996   The Blithedale Romance (1852) is Nathaniel Ha...
# 559997   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...
# 559998   Vinyl Cafe Notebooks: a collection of essays ...
#
# [559999 rows x 3 columns]

# %%
train_data.columns = ['a','b','c']
uni = pd.unique(train_data['a'])
train_data.head()
# Out:
#    a                                  b  \
# 0  1                     Schwan-Stabilo
# 1  1                         Q-workshop
# 2  1  Marvell Software Solutions Israel
# 3  1        Bergan Mercy Medical Center
# 4  1                 The Unsigned Guide
#
#                                                    c
# 0   Schwan-STABILO is a German maker of pens for ...
# 1   Q-workshop is a Polish company located in Poz...
# 2   Marvell Software Solutions Israel known as RA...
# 3   Bergan Mercy Medical Center is a hospital loc...
# 4   The Unsigned Guide is an online contacts dire...

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def cleanText(text):
    text = BeautifulSoup(text, "lxml").text
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) 
    return text
train_data['c'] = train_data['c'].apply(cleanText)
train_data
# Out:
#          a                                                  b  \
# 0        1                                     Schwan-Stabilo
# 1        1                                         Q-workshop
# 2        1                  Marvell Software Solutions Israel
# 3        1                        Bergan Mercy Medical Center
# 4        1                                 The Unsigned Guide
# 5        1                                  Rest of the world
# 6        1                                         Globoforce
# 7        1                                          Rompetrol
# 8        1                                    Wave Accounting
# 9        1                                 Angstrem (company)
# 10       1                                    I-innovate (UK)
# 11       1                                                JVC
# 12       1                                           Toei Bus
# 13       1                                  Tear Drop Records
# 14       1  Presses polytechniques et universitaires romandes
# 15       1                                           Websense
# 16       1                            Adventist Health System
# 17       1                                           CIB Bank
# 18       1                               Orfanato Music Group
# 19       1                                   SCAN Health Plan
# 20       1                                       Rudolf Kämpf
# 21       1                                   De Wendel family
# 22       1                         Mansfield Building Society
# 23       1                                     Witcomb Cycles
# 24       1                                Goldilocks Bakeshop
# 25       1                         Guardian Assurance Company
# 26       1                                             Shiply
# 27       1                    Orange Music Electronic Company
# 28       1                                  Rytec Corporation
# 29       1                              Cavity Search Records
# ...     ..                                                ...
# 559969  14                                                NME
# 559970  14                                       The Londoner
# 559971  14                        Formal Aspects of Computing
# 559972  14                                          Hayom Yom
# 559973  14                      Swords Against the Shadowland
# 559974  14            Aruvu Rezuru: Kikaijikake no Yōseitachi
# 559975  14                                  Tintin (magazine)
# 559976  14                     The Tenth Man (Chayefsky play)
# 559977  14                                  Dramatical Murder
# 559978  14               A Dictionary of Modern English Usage
# 559979  14                                            Assayad
# 559980  14                                   Loveless (manga)
# 559981  14                                The American Hebrew
# 559982  14                                Montanan (magazine)
# 559983  14                                  Black Out (novel)
# 559984  14                               Gold Digger (comics)
# 559985  14                             Dealer's Choice (play)
# 559986  14                                     Phuket Gazette
# 559987  14                          If I Forget Thee Oh Earth
# 559988  14                      The Lincoln Conspiracy (book)
# 559989  14                                 Endocrine Research
# 559990  14                           A Thousand Splendid Suns
# 559991  14                                     Western People
# 559992  14                            Mademoiselle (magazine)
# 559993  14                                Scoliosis (journal)
# 559994  14                                   Barking in Essex
# 559995  14                                   Science & Spirit
# 559996  14                             The Blithedale Romance
# 559997  14                                Razadarit Ayedawbon
# 559998  14                           The Vinyl Cafe Notebooks
#
#                                                         c
# 0       schwanstabilo german maker pens writing colour...
# 1       qworkshop polish company located pozna special...
# 2       marvell software solutions israel known radlan...
# 3       bergan mercy medical center hospital located o...
# 4       unsigned guide online contacts directory caree...
# 5       within sports games played international compe...
# 6       globoforce multinational company coheadquarter...
# 7       rompetrol group nv romanian oil company operat...
# 8       wave brand name suite online small business so...
# 9       angstrem group russian named angstrom group ru...
# 10      iinnovate uk londonbased independent record la...
# 11      victor company japan ltd nippon bikut kabushik...
# 12      toei bus toei basu bus service operated bus se...
# 13      tear drop records record label founded winnie ...
# 14      presses polytechniques et universitaires roman...
# 15      websense san diegobased company specializing c...
# 16      adventist health system nonprofit health care ...
# 17      cib bank secondbiggest commercial bank hungary...
# 18      orfanato music group omg puerto rican record l...
# 19      scan health plan scan notforprofit health plan...
# 20      rudolf kmpf porcelain manufacturer czech republic
# 21      de wendel family industrialist family lorraine...
# 22      mansfield building society uk building society...
# 23      witcomb cycles formerly known witcomb lightwei...
# 24      goldilocks bakeshop bakeshop chain based phili...
# 25      guardian assurance company large british insur...
# 26      shiply ukbased limited company providing inter...
# 27      orange music electronic company british amplif...
# 28      rytec corporation american manufacturer highcy...
# 29      cavity search records record label based portl...
# ...                                                   ...
# 559969  new musical express popularly known acronym nm...
# 559970  londoner newsletter style newspaper published ...
# 559971  formal aspects computing fac peerreviewed scie...
# 559972  hayom yom hebrew today day calendar hebrew yea...
# 559973  swords shadowland fantasy novel robin wayne ba...
# 559974  aruvu rezuru kikaijikake yseitachi lit arve re...
# 559975  tintin magazine french le journal de tintin du...
# 559976                       tenth man 1959 american play
# 559977  dramatical murder doramatikaru md styled drama...
# 559978  dictionary modern english usage 1926 henry wat...
# 559979  assayad weekly arabic news magazine published ...
# 559980  loveless raburesu ongoing fantasy manga yun kg...
# 559981  american hebrew weekly jewish magazine publish...
# 559982  montanan university montanas alumni magazine c...
# 559983  black psychological thriller bestselling autho...
# 559984  gold digger mangastyle comic book series writt...
# 559985  dealers choice play patrick marber first perfo...
# 559986  phuket gazette weekly englishlanguage tabloid ...
# 559987  forget thee earth short story written arthur c...
# 559988  lincoln conspiracy book david w balsiger charl...
# 559989  endocrine research peerreviewed medical journa...
# 559990  thousand splendid suns 2007 novel afghanameric...
# 559991  western people weekly local newspaper publishe...
# 559992  mademoiselle womens magazine first published 1...
# 559993  scoliosis issn 17487161 openaccess peerreviewe...
# 559994  barking essex black comedy play directed harry...
# 559995  science spirit discontinued american bimonthly...
# 559996  blithedale romance 1852 nathaniel hawthornes t...
# 559997  razadarit ayedawbon burmese burmese chronicle ...
# 559998  vinyl cafe notebooks collection essays vinyl c...
#
# [559999 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(train_data["c"],train_data["a"],test_size = 0.5)

# %%
x_train
# Out:
# 265109    reckart mill also known albright mill historic...
# 408405    abarema acreana tree species legume family fab...
# 231392    ps rms douglas ii 45470 second vessel lines hi...
# 23598     isgec heavy engineering ltd diversified global...
# 289485                           chapelco river river chile
# 446200    memories best elaine paige compilation album e...
# 349136    mashaye 5 gazabad persian 5 also romanized mas...
# 427348    rhynchopsidium genus flowering plants daisy fa...
# 33071     gooderham worts canadian company largest disti...
# 117705    monster maezuka maezuka monsuta born atsushi m...
# 96729     dorothy whipple ne stirrup 1893 blackburn lanc...
# 175904    william mordaunt furneaux dean winchester earl...
# 178984    charles elson roemer iv known chas roemer born...
# 290352    trus madi range range mountains sabah borneo i...
# 234549    curtiss v8 motorcycle 269 cu 4410 cc v8 engine...
# 520375    father hilarys holiday 1965 novel scottish wri...
# 74064     joseph vaz college wennappuwa commonly known j...
# 342098    dehe bala persian also romanized dehe bl also ...
# 510410    stamp day superman 1954 blackandwhite short fi...
# 11236     ceyenar chemicals private limited short name c...
# 151759    francis charles polsfoot april 19 1927 april 5...
# 136146    wairangi koopu born 2 april 1980 opotiki new z...
# 405054    burmeistera asplundii species plant campanulac...
# 38126     national fast freight multimodal transportatio...
# 45459     guru ravidas ayurved university public univers...
# 428799    epidendrum dendrobioides species orchid genus ...
# 298544    rotria river tributary rmnicul srat river romania
# 43057     thadomal shahani engineering college tsec engi...
# 178503    michelle e schimel born august 8 1957 democrat...
# 57935     loreto convent school girls school delhi india...
#                                 ...
# 92521     andrija kai mioi pronounced ndrija ktit mit ap...
# 25615     full compass systems national retailer profess...
# 116965    ingrid noll married name ingrid gullatz born 2...
# 337726    doluca village district kahta adyaman province...
# 556813    carcase hounds novel kenyan writer meja mwangi...
# 61422     atomic minerals directorate exploration resear...
# 93876     ken laszlo born gianni coraini 1954 italo disc...
# 65135     penn state hazleton commonwealth campus pennsy...
# 118360    edwin lawrence godkin october 2 1831 may 21 19...
# 429786    scoparia dulcis species flowering plant planta...
# 162372    said halim pasha albanian said halimi 18 janua...
# 526819    flare canadian fashion magazine published roge...
# 375201    steyskalomyza monotypic genus flies family dry...
# 190503    major roy gerard corcor brock b 1884 british a...
# 481111    mayhem sunday afternoon last three documentari...
# 341904    gavzan mahallehye rudbast persian also romaniz...
# 389681    percolaus genus beetles family carabidae conta...
# 327059    atra chal persian also romanized atr chl villa...
# 361613                       dexippus genus jumping spiders
# 245997    brick tavern stand also known clawson house hi...
# 512356    mickybo 2004 northern irish comedydrama film w...
# 491167    clearing eye first dvd release los angeles pos...
# 323526    anjeh persian village pian rural district cent...
# 326187    chinnaganjam village mandal prakasam district ...
# 551403    fox continuation story fictional protagonist inda
# 463809    aprs studio album mostly french covers iggy po...
# 510840    balibo 2009 australian war film follows story ...
# 424738    jarava genus subfamily pooideae true grass fam...
# 267280    huis ten bosch dutch pronunciation ys tn bs en...
# 375032    blue finch yellowbilled blue finch porphyrospi...
# Name: c, Length: 279999, dtype: object

# %%
tfidf = TfidfVectorizer(stop_words= 'english', sublinear_tf= True)
tfidf
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=True,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
tfidf_fitted = tfidf.fit(x_train)

# %%
tfidf_scores = tfidf_fitted.transform(x_train)

# %%
tfidf_scores
# Out:
# <279999x491147 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6732697 stored elements in Compressed Sparse Row format>

# %%
x_test
# Out:
# 452628    glint kindling folk album released 1979 robin ...
# 44060     tecumseh high school public high school near n...
# 426986    nepenthes copelandii npniz koplndia edwin cope...
# 52254     central conservatory music simplified chinese ...
# 345037    pir mikail persian also romanized pr mkl also ...
# 489422    kreutzer sonata 2008 film directed bernard ros...
# 339097    avclar village district ske aydn province turk...
# 63348     jnana prabodhini prashala high school located ...
# 148630    jean mathonet 6 october 1925 bverc malmedy 22 ...
# 84309     patricia buckley moss also known p buckley mos...
# 424427    ambrosina genus family araceae consists one sp...
# 351147    sawowice swavvits village administrative distr...
# 472734    mitch together standup comedian mitch hedbergs...
# 426073    buddleja hever pride cultivar hybrid buddleja ...
# 416974    acrotriche depressa commonly known native curr...
# 118684    felix stone moscheles 8 february 1833 22 decem...
# 199028    guillaumeandr fauteux october 20 1874 septembe...
# 429600          lucilia genus flowering plants daisy family
# 293804          jilul mic river tributary jil river romania
# 397646    tony bin 19832000 irishbred thoroughbred raceh...
# 438337    crassocephalum bougheyanum species flowering p...
# 462608    plastic skies seventh album australian punk ro...
# 391241    eleutherodactylus alticola species frog leptod...
# 236379    uss foote torpedo boat 3 tb3 coast torpedo boa...
# 401063    conospermum genus 53 species family proteaceae...
# 146001    brett dancer commonly incorrectly referred bre...
# 106512    mort drucker born march 22 1929 american caric...
# 70673     naogaon kd government high school bengali publ...
# 305877    mount peabody 9216 feet 2809 located livingsto...
# 436557    casearia mauritiana species plant salicaceae f...
#                                 ...
# 96335     aleksandra aleksandrovna ekster russian ukrain...
# 352526    darrehye baz persian also romanized darrehye b...
# 405322    helenium bolanderi species flowering plant dai...
# 543576    devils work 1991 novella alan judd guardian fi...
# 455247    love jerome kern album pianist kenny drew reco...
# 355612    kandalica village municipality knjaevac serbia...
# 253871    cedarvale also known hillsboro ranch dude ranc...
# 407272    pelargonium cotyledonis local name old father ...
# 531956    starslayer log jolly roger american comic book...
# 57414     college law university saskatchewan university...
# 333225    mohammadabade olya persian also romanized moam...
# 451574    greatest hits compilation album british rock g...
# 162336    nadendla bhaskara rao born 23 june 1935 guntur...
# 274045    cnl center city commons complex buildings down...
# 117976    philippe lefebvre french actor screenwriter pe...
# 362999    sunda scops owl otus lempiji small brown owl s...
# 82914     elena palmer renowned german journalist author...
# 399275    noteridae family water beetles closely related...
# 416962    opuntia also known nopales paddle cactus see g...
# 285601    canal de caen la mer english canal caen sea al...
# 388025           leucoedemia genus moths family lyonetiidae
# 549812    spitfire troubleshooters renamed spitfire issu...
# 33571     nodeone commercial opensource software company...
# 360221    bryotropha domestica moth gelechiidae family f...
# 261036    fourteenth ward industrial school located 2562...
# 277145    grt grand chennai luxury hotel located nagar c...
# 318900    rushforth lake lake hayes river drainage basin...
# 341440    aliyak persian also romanized alyak alak villa...
# 542624    2001 book unfinished twentieth century author ...
# 439031    shorea palosapis also called philippine mahoga...
# Name: c, Length: 280000, dtype: object

# %%
# Deicsion Tree classifier
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(tfidf_scores, y_train)

# %%
tfidf_scores_test = tfidf_fitted.transform(x_test)

# %%
tfidf_scores_test
# Out:
# <280000x491147 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6398859 stored elements in Compressed Sparse Row format>

# %%
accuracy = clf.score(tfidf_scores_test,y_test)
accuracy
# Out:
# 0.9229

# %%
# Ordinary Least Squares
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(tfidf_scores, y_train)

# %%
reg.score(tfidf_scores_test,y_test)

# %%
# Ridge regression and classification
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit(tfidf_scores, y_train)

# %%
reg.score(tfidf_scores_test,y_test)

# %%
# SVM Classifier
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(tfidf_scores, y_train)

# %%
clf.score(tfidf_scores_test,y_test)

# %%
# SVM Regressor
clf = svm.LinearSVR()
clf.fit(tfidf_scores, y_train)

# %%
clf.score(tfidf_scores_test,y_test)
